# %% [markdown]
# # Using WebSocket Client

# %%
import json
import requests
import redis
import websocket

# %%
ws=websocket.WebSocket()

# %%
import random,time

# %%
ws.connect('ws://localhost:8000/ws/polData/')

# %%
for i in range(1000):
    time.sleep(3)
    ws.send(json.dumps({'value':random.randint(1,100)}))

# %%
# Out:
#   File "<ipython-input-29-5c47c4ed607e>", line 1
#     python -m websockets ws://localhost:8000/ws/polData/
#               ^
# SyntaxError: invalid syntax

# %%
python -m websocket ws://localhost:8000/ws/polData/
# Out:
#   File "<ipython-input-30-95abff849aa2>", line 1
#     python -m websocket ws://localhost:8000/ws/polData/
#               ^
# SyntaxError: invalid syntax
