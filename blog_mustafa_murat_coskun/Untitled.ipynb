# %%
from django_for_jupyter import init_django

# %%
init_django("blog_mustafa_murat_coskun")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-5-9e2f38e127b7> in <module>
# ----> 1 init_django("blog_mustafa_murat_coskun")
#
# ~/Desktop/repos/DjangoProjects/blog_mustafa_murat_coskun/django_for_jupyter.py in init_django(project_name)
#      17     os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
#      18     import django
# ---> 19     django.setup()
#
# ~/anaconda3/lib/python3.8/site-packages/django/__init__.py in setup(set_prefix)
#      22             '/' if settings.FORCE_SCRIPT_NAME is None else settings.FORCE_SCRIPT_NAME
#      23         )
# ---> 24     apps.populate(settings.INSTALLED_APPS)
#
# ~/anaconda3/lib/python3.8/site-packages/django/apps/registry.py in populate(self, installed_apps)
#      81                 # Prevent reentrant calls to avoid running AppConfig.ready()
#      82                 # methods twice.
# ---> 83                 raise RuntimeError("populate() isn't reentrant")
#      84             self.loading = True
#      85
#
# RuntimeError: populate() isn't reentrant

# %%
pip install django-crispy-forms
# Out:
# Collecting django-crispy-forms
#   Downloading django_crispy_forms-1.9.2-py3-none-any.whl (108 kB)
#      |████████████████████████████████| 108 kB 925 kB/s eta 0:00:01
# Installing collected packages: django-crispy-forms
# Successfully installed django-crispy-forms-1.9.2
# Note: you may need to restart the kernel to use updated packages.
